# %% [markdown]
# Start of pandas

# %% [markdown]
# Series

# %%
import pandas as pd
S = pd.Series([10,20,30] , index=["a", "b","c"])
print(S)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Data Frame

# %%
data = {
    "Name":["Alice","Bob","Kelly"],
    "Age" : [20,19,21]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   20
# 1    Bob   19
# 2  Kelly   21

# %%
#Example 1 
import pandas as pd
url =  ("https://archieve.ics.uci.edu/mldf = pd.read_csv(url , header=None , name/machine-learning-databases/iris/iris.data")
column_names = [" sepal_length", "sepal_width", "petal_lenght", "petal_width","class" ]
s = column_names , index_col = False)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Python314\Lib\urllib\request.py:1321, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1320 try:
# -> 1321     h.request(req.get_method(), req.selector, req.data, headers,
#    1322               encode_chunked=req.has_header('Transfer-encoding'))
#    1323 except OSError as err: # timeout error
#
# File c:\Python314\Lib\http\client.py:1367, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1366 """Send a complete request to the server."""
# -> 1367 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Python314\Lib\http\client.py:1413, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1412     body = _encode(body, 'body')
# -> 1413 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...
